# %% [markdown]
# <a href="https://colab.research.google.com/github/18cse063SharmisthaPatel/sharmistha/blob/main/DAAssignment118cse063.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create a vector of pies
x <- c(130,45,75,65,35)

# Create a vector of labels
mylabel <- c("CSE", "CST", "ECE", "MECH" , "BIO")

# Display the pie chart with labels
pie(x, label = mylabel, main = "Students")
# Out:
# Plot with title “Students”

# %%
# x-axis values
Year <- c("2010", "2011", "2012", "2013" , "2014")

# y-axis values
Sales <- c(1250, 1325, 1275, 1175, 1350)

barplot(Sales, names.arg = x, col = "black")
# Out:
# plot without title

# %%
# x-axis values
Year <- c("2010", "2011", "2012", "2013" , "2014")

# y-axis values
Purchase <- c(1350, 1375, 1459, 1450, 1775)

barplot(Purchase, names.arg = x, col = "pink")
# Out:
# plot without title
